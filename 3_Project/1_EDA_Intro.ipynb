# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
import seaborn as sns
from datasets import load_dataset

dataset=load_dataset('lukebarousse/data_jobs')

df=dataset['train'].to_pandas()

df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
def clean_string(string_list):
    if pd.notna(string_list):
        return ast.literal_eval(string_list)
    else:
        return string_list
df['job_skills']=df['job_skills'].apply(clean_string)

# %%
df_US=df[(df['job_title_short']=='Data Analyst') & (df['job_country']== 'United States')]
df_US
# Out:
#        job_title_short  ...                                    job_type_skills
# 36        Data Analyst  ...                                               None
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 79        Data Analyst  ...  {'analyst_tools': ['sas', 'word', 'excel'], 'p...
# 93        Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# ...                ...  ...                                                ...
# 785603    Data Analyst  ...  {'analyst_tools': ['excel'], 'other': ['flow']...
# 785626    Data Analyst  ...                      {'sync': ['microsoft teams']}
# 785685    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785703    Data Analyst  ...                                               None
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# [67816 rows x 17 columns]

# %%
df_plot=df_US['job_location'].value_counts().head(10).to_frame()
sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False )
sns.despine()
plt.ylabel('')
plt.xlabel('No. of Jobs')
plt.title('No. of Jobs per job title')
# Out:
# Text(0.5, 1.0, 'No. of Jobs per job title')

# %%
fig, ax=plt.subplots(1,3)
fig.set_size_inches((12,5))
dict_columns={
    'job_work_from_home':'Work from Home',
    'job_no_degree_mention':'Degree Requirement',
    'job_health_insurance': 'Health insurance'
}
for i,(column,title) in enumerate(dict_columns.items()):
    df_US[column].value_counts().plot(kind='pie',ax=ax[i],startangle=90, autopct='%1.1f%%')
    ax[i].set_ylabel('')
    ax[i].set_title(title)

# %%
df_plot=df_US['company_name'].value_counts().head(10).to_frame()
sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False )
sns.despine()
plt.ylabel('')
plt.xlabel('No. of Jobs')
plt.title('Count of Companies per job title')
# Out:
# Text(0.5, 1.0, 'Count of Companies per job title')
