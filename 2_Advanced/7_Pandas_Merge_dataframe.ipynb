# %%
import pandas as pd
import matplotlib.pyplot as plt

#IMPORTING DATASET
from datasets import load_dataset
dataset=load_dataset('lukebarousse/data_jobs') 
df=dataset['train'].to_pandas()

#CLEANING THE DATA
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df_US=df[df['job_country']=='United States'].copy()
df_US['job_posted_month']=df_US['job_posted_date'].dt.strftime('%B')
df_pivot=df_US.pivot_table(index='job_posted_month',columns='job_title_short', aggfunc='size')
df_pivot.reset_index(inplace=True)
df_pivot['month_no']=pd.to_datetime(df_pivot['job_posted_month'], format='%B').dt.month
df_pivot.sort_values('month_no', inplace=True)
df_pivot.set_index('job_posted_month', inplace=True)
df_pivot.drop(columns='month_no', inplace=True)
#df_pivot.drop(columns='level_0', inplace=True)
df_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_software_pivot=pd.read_csv("https://lukeb.co/software_csv", index_col='job_posted_month')

# %%
df_merge_jobs=df_pivot.merge(df_software_pivot, on='job_posted_month')
df_merge_jobs
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_3_jobs=df_merge_jobs.sum()
top_3_jobs=top_3_jobs.sort_values(ascending=False).head().index.to_list()

# %%
df_merge_jobs[top_3_jobs].plot(kind='line')
plt.title('Trend of job postings in US')
plt.xlabel('2023')
plt.ylabel('Job count')
plt.ylim(0,20000)
plt.legend()
plt.show()
